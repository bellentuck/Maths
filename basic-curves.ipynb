# %%
import matplotlib.pyplot as plt
from math import *
import numpy as np

# %%
def graph(formula, graphDomain=range(-10,11)):
    x = np.array(graphDomain)
    y = eval(formula)
    plt.plot(x, y)
    plt.show()

# %%
graph('-x**2')
